# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Identify dependencies and import the CSV file

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime
import os
import scipy.stats as sem

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("city_weather.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations.  The command will go from lower range to upper range, a length of 1500.
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

# Zip the latitudes and longituted together to create a tuple
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'The cities list is {len(cities)} entries long.')
# Out:
# The cities list is 620 entries long.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Setup variables and lists to hold responses 
c = 0                   # counter for the loop to remove bad information
error = 0               # counter to track errors
removed_cities = []     # list to collect removed city names because weather data did not exist

# Identify the columns in the DataFrame where the responses will be stored
columns = ['City ID', 'City', 'Latitude', 'Longitude', 'Max Temperature (F)', 'Humidity (%)', 'Clouds (%)', 'Wind Speed (mph)', 'Country', 'DT']
data_df = pd.DataFrame(columns=columns)

# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    # Initialize lists to be used
    values = []         # list of all of the returned values from the API call
    data = []           # the dictionary that will be appended to the DataFrame
    
    # Perform the request to the API to get the current weather data for the city 
    response_json = requests.get(query_url + city).json()
    
    # Append the city ID, city name latitude, temperature, humidity, clouds and wind speed to the DataFrame
    try:
        # Pull the data from the API JSON for the required fields
        city_id = response_json['id']
        lat = response_json['coord']['lat']
        lng = response_json['coord']['lon']
        temp_max = response_json['main']['temp_max']
        humidity = float(response_json['main']['humidity'])
        clouds = float(response_json['clouds']['all'])
        wind = response_json['wind']['speed']
        country = response_json['sys']['country']
        dt = response_json['dt']
        
        # create a list of the data values for the city
        values = [city_id, city, lat, lng, temp_max, humidity, clouds, wind, country, dt]
        print(f'The data from the {c} city call is as follows: {values}.')
        
        # zip the column names to the values
        zipped = zip(columns, values)
        
        # create a dictionary of the zipped data
        a_dictionary = dict(zipped)
        
        # append the dictionary to the variable data
        data.append(a_dictionary)
        
        # append the dictionary data into the DataFrame
        data_df = data_df.append(data, True)
    
    except KeyError:
        # If a KeyError, create an error message.
        print(f"Failed on {c} try.")
        
        # Append the city name that does not have weather data to a list, and remove from the main cities list
        removed_cities.append(cities.pop(c))
        
        # increase the counter of the error count
        error = error + 1
    
    # increase the counter of the overall iteration count
    c = c + 1

# Print summaries of the iteration of cities in the main city list.  
print('The API query is complete.')
print('--------------------')
print(f'The loop ran for {c} times to the {c-1} index.')
print(f'There were {error} errors found when trying to look up weather for cities.')
print(f'The removed cities from the original list are as follows: {removed_cities}.')
print('--------------------')
print(f'The cities list is now {len(cities)} long.')
# Out:
# The data from the 0 city call is as follows: [6185377, 'yellowknife', 62.456, -114.3525, -15.59, 90.0, 75.0, 4.61, 'CA', 1644345519].
# The data from the 1 city call is as follows: [2068110, 'kununurra', -15.7667, 128.7333, 80.58, 89.0, 75.0, 0, 'AU', 1644345732].
# The data from the 2 city call is as follows: [2027275, 'bada', 51.392, 109.8717, 0.21, 98.0, 100.0, 2.95, 'RU', 1644345733].
# Failed on 3 try.
# The data from the 4 city call is as follows: [5880054, 'barrow', 71.2906, -156.7887, -30.98, 100.0, 20.0, 8.05, 'US', 1644345742].
# The data from the 5 city call is as follows: [1640902, 'kawalu', -7.3817, 108.2082, 73.92, 92.0, 100.0, 1.03, 'ID', 1644345742].
# The data from the 6 city call is as follows: [2019488, 'namtsy', 62.7161, 129.6658, -34.49, 100.0, 100.0, 1.95, 'RU', 1644345743].
# Failed on 7 try.
# The data from the 8 city call is as follows: [3874787, 'punta arenas', -53.15, -70.9167, 59.11, 44.0, 75.0, 21.85, 'CL', 1644345646].
# The data from the 9 city call is as follows: [4035715, 'avarua', -21.2078, -159.775, 77.05, 94.0, 75.0, 8.05, 'CK', 1644345743].
# The data from the 10 city call is as follows: [104515, 'mecca', 21.4267, 39.8261, 72.86, 75.0, 2.0, 3.09, 'SA', 1644345744].
# The data from the 11 city call is as follows: [5122534, 'jamestown', 42.097, -79.2353, 29.08, 60.0, 100.0, 13.8, 'US', 1644345725].
# The data from the 12 city call is as follows: [5106841, 'albany', 42.6001, -73.9662, 37.02, 72.0, 100.0, 7, 'US', 1644345744].
# The data from the 13 city call is as follows: [2074865, 'carnarvon', -24.8667, 113.6333, 75.27, 73.0, 0.0, 16.11, 'AU', 1644345745].
# The data from the 14 city call is as follows: [2075265, 'busselton', -33.65, 115.3333, 55.09, 82.0, 0.0, 7.58, 'AU', 1644345745].
# The data from the 15 city call is as follows: [6201424, 'mataura', -46.1927, 168.8643, 47.48, 98.0, 100.0, 2.95, 'NZ', 1644345745].
# The data from the 16 city call is as follows: [3440777, 'rocha', -34.4833, -54.3333, 73.06, 52.0, 1.0, 10.13, 'UY', 1644345746].
# The data from the 17 city call is as follows: [3577430, 'road town', 18.4167, -64.6167, 82.44, 54.0, 20.0, 14.97, 'VG', 1644345746].
# The data from the 18 city call is as follows: [2171099, 'codrington', -38.2667, 141.9667, 67.55, 67.0, 100.0, 4.63, 'AU', 1644345746].
# The data from the 19 city call is as follows: [3491355, 'black river', 18.0264, -77.8487, 80.98, 67.0, 24.0, 10.56, 'JM', 1644345747].
# The data from the 20 city call is as follows: [2124611, 'kholodnyy', 62.7167, 147.95, -32.66, 88.0, 18.0, 0.54, 'RU', 1644345747].
# The data from the 21 city call is as follows: [2022232, 'khrebtovaya', 56.7032, 104.2494, -8.21, 97.0, 100.0, 4.92, 'RU', 1644345748].
# The data from the 22 city call is as follows: [1006984, 'east london', -33.0153, 27.9116, 76.14, 88.0, 0.0, 9.22, 'ZA', 1644345748].
# The data from the 23 city call is as follows: [1282256, 'hithadhoo', -0.6, 73.0833, 82.83, 69.0, 100.0, 14.99, 'MV', 1644345748].
# The data from the 24 city call is as follows: [2163355, 'hobart', -42.8794, 147.3294, 55.27, 86.0, 22.0, 0, 'AU', 1644345618].
# The data from the 25 city call is as follows: [6166739, 'timmins', 48.4669, -81.3331, 19.22, 73.0, 75.0, 4.61, 'CA', 1644345749].
# The data from the 26 city call is as follows: [5855927, 'hilo', 19.7297, -155.09, 74.62, 74.0, 40.0, 8.05, 'US', 1644345677].
# The data from the 27 city call is as follows: [6355222, 'yulara', -25.2406, 130.9889, 75.04, 83.0, 40.0, 5.75, 'AU', 1644345750].
# The data from the 28 city call is as follows: [3369157, 'cape town', -33.9258, 18.4232, 71.1, 70.0, 0.0, 14.97, 'ZA', 1644345711].
# The data from the 29 city call is as follows: [3466704, 'castro', -24.7911, -50.0119, 72.7, 75.0, 75.0, 5.12, 'BR', 1644345751].
# The data from the 30 city call is as follows: [5110365, 'broome', 42.2506, -75.833, 35.1, 71.0, 100.0, 6.91, 'US', 1644345752].
# The data from the 31 city call is as follows: [3430863, 'mar del plata', -38.0023, -57.5575, 71.62, 79.0, 0.0, 12.66, 'AR', 1644345752].
# The data from the 32 city call is as follows: [3833367, 'ushuaia', -54.8, -68.3, 55.06, 47.0, 40.0, 18.41, 'AR', 1644345513].
# Failed on 33 try.
# The data from the 34 city call is as follows: [3366880, 'hermanus', -34.4187, 19.2345, 68.81, 92.0, 85.0, 7.05, 'ZA', 1644345753].
# The data from the 35 city call is as follows: [3355672, 'luderitz', -26.6481, 15.1594, 74.75, 68.0, 71.0, 1.41, 'NA', 1644345753].
# The data from the 36 city call is as follows: [1492566, 'severo-yeniseyskiy', 60.3725, 93.0408, -25.26, 100.0, 67.0, 1.41, 'RU', 1644345753].
# The data from the 37 city call is as follows: [4030556, 'rikitea', -23.1203, -134.9692, 78.33, 73.0, 40.0, 10.65, 'PF', 1644345754].
# The data from the 38 city call is as follows: [4164138, 'miami', 25.7743, -80.1937, 82.42, 66.0, 40.0, 11.99, 'US', 1644345038].
# The data from the 39 city call is as follows: [1861416, 'ishigaki', 24.3448, 124.1572, 67.24, 77.0, 100.0, 20.74, 'JP', 1644345754].
# The data from the 40 city call is as follows: [4020109, 'atuona', -9.8, -139.0333, 78.12, 78.0, 22.0, 17.56, 'PF', 1644345755].
# The data from the 41 city call is as follows: [2126123, 'chokurdakh', 70.6333, 147.9167, -43.83, 100.0, 97.0, 5.41, 'RU', 1644345755].
# Failed on 42 try.
# The data from the 43 city call is as follows: [1486321, 'yar-sale', 66.8333, 70.8333, 0.23, 89.0, 100.0, 16.08, 'RU', 1644345756].
# The data from the 44 city call is as follows: [779554, 'honningsvag', 70.9821, 25.9704, 29.95, 74.0, 75.0, 23.02, 'NO', 1644345756].
# The data from the 45 city call is as follows: [2206939, 'bluff', -46.6, 168.3333, 47.8, 91.0, 100.0, 12.1, 'NZ', 1644345756].
# The data from the 46 city call is as follows: [175967, 'mporokoso', -9.3727, 30.125, 62.49, 95.0, 90.0, 2.59, 'ZM', 1644345757].
# Failed on 47 try.
# The data from the 48 city call is as follows: [780717, 'batsfjord', 70.6345, 29.7185, 30.42, 92.0, 85.0, 15.55, 'NO', 1644345757].
# The data from the 49 city call is as follows: [1735106, 'georgetown', 5.4112, 100.3354, 78.89, 91.0, 40.0, 3.44, 'MY', 1644345664].
# The data from the 50 city call is as follows: [2264557, 'ponta do sol', 32.6667, -17.1, 71.06, 61.0, 41.0, 8.66, 'PT', 1644345758].
# The data from the 51 city call is as follows: [5282297, 'bethel', 41.3712, -73.414, 45.1, 79.0, 100.0, 11.5, 'US', 1644345759].
# The data from the 52 city call is as follows: [6148373, 'sioux lookout', 50.1001, -91.917, 19.78, 79.0, 100.0, 11.5, 'CA', 1644345759].
# The data from the 53 city call is as follows: [2084442, 'vanimo', -2.6741, 141.3028, 76.78, 90.0, 90.0, 1.63, 'PG', 1644345760].
# The data from the 54 city call is as follows: [3418910, 'upernavik', 72.7868, -56.1549, -15.48, 91.0, 100.0, 6.26, 'GL', 1644345760].
# The data from the 55 city call is as follows: [5861897, 'fairbanks', 64.8378, -147.7164, -6.99, 72.0, 75.0, 6.91, 'US', 1644345465].
# The data from the 56 city call is as follows: [1507390, 'dikson', 73.5069, 80.5464, 3.4, 94.0, 100.0, 22.1, 'RU', 1644345760].
# The data from the 57 city call is as follows: [2022572, 'khatanga', 71.9667, 102.5, 2.21, 79.0, 100.0, 17.63, 'RU', 1644345761].
# The data from the 58 city call is as follows: [2381972, 'adrar', 20.5022, -10.0711, 73.09, 9.0, 73.0, 9.53, 'MR', 1644345761].
# The data from the 59 city call is as follows: [338554, 'dubti', 11.7361, 41.0853, 78.4, 46.0, 19.0, 17.43, 'ET', 1644345761].
# The data from the 60 city call is as follows: [934322, 'mahebourg', -20.4081, 57.7, 77.29, 83.0, 40.0, 3.44, 'MU', 1644345762].
# The data from the 61 city call is as follows: [527321, 'mezen', 65.8522, 44.24, 17.65, 93.0, 100.0, 10.31, 'RU', 1644345762].
# The data from the 62 city call is as follows: [1488903, 'turukhansk', 65.8167, 87.9833, -15.45, 91.0, 100.0, 4.03, 'RU', 1644345763].
# The data from the 63 city call is as follows: [7601762, 'bairiki', 1.3292, 172.9752, 80.6, 83.0, 40.0, 6.91, 'KI', 1644345763].
# The data from the 64 city call is as follows: [1636806, 'majene', -3.5403, 118.9707, 77.56, 87.0, 100.0, 4.59, 'ID', 1644345763].
# The data from the 65 city call is as follows: [3466165, 'cidreira', -30.1811, -50.2056, 74.98, 65.0, 49.0, 14.14, 'BR', 1644345764].
# The data from the 66 city call is as follows: [2034651, 'suileng', 47.25, 127.0833, 3.54, 100.0, 100.0, 6.91, 'CN', 1644345764].
# The data from the 67 city call is as follows: [933995, 'souillac', -20.5167, 57.5167, 77.38, 83.0, 40.0, 3.44, 'MU', 1644345764].
# The data from the 68 city call is as follows: [2194098, 'ahipara', -35.1667, 173.1667, 73.58, 94.0, 94.0, 7.09, 'NZ', 1644345765].
# The data from the 69 city call is as follows: [1015776, 'bredasdorp', -34.5322, 20.0403, 69.12, 73.0, 1.0, 8.05, 'ZA', 1644345765].
# The data from the 70 city call is as follows: [5847486, 'kailua', 21.4022, -157.7394, 77.65, 69.0, 20.0, 6.91, 'US', 1644345765].
# The data from the 71 city call is as follows: [3386931, 'tamandare', -8.7597, -35.1047, 83.48, 65.0, 0.0, 11.14, 'BR', 1644345766].
# The data from the 72 city call is as follows: [2112309, 'katsuura', 35.1333, 140.3, 42.91, 84.0, 85.0, 10.04, 'JP', 1644345766].
# The data from the 73 city call is as follows: [2510075, 'utiel', 39.5667, -1.2, 47.64, 76.0, 0.0, 4.81, 'ES', 1644345767].
# The data from the 74 city call is as follows: [2777972, 'grieskirchen', 48.2333, 13.8333, 45.72, 74.0, 97.0, 11.05, 'AT', 1644345767].
# The data from the 75 city call is as follows: [924206, 'phalombe', -15.8064, 35.6507, 68.04, 87.0, 8.0, 2.04, 'MW', 1644345767].
# Failed on 76 try.
# The data from the 77 city call is as follows: [286621, 'salalah', 17.0151, 54.0924, 75.29, 14.0, 0.0, 14.97, 'OM', 1644345768].
# The data from the 78 city call is as follows: [2729907, 'longyearbyen', 78.2186, 15.6401, 17.44, 67.0, 75.0, 8.05, 'SJ', 1644345700].
# The data from the 79 city call is as follows: [2738381, 'lata', 40.1629, -8.3327, 63.01, 58.0, 0.0, 4.41, 'PT', 1644345768].
# The data from the 80 city call is as follows: [53372, 'odweyne', 9.4092, 45.064, 68.36, 42.0, 36.0, 7.92, 'SO', 1644345769].
# Failed on 81 try.
# The data from the 82 city call is as follows: [3424607, 'tasiilaq', 65.6145, -37.6368, 19.56, 81.0, 100.0, 8.46, 'GL', 1644345769].
# The data from the 83 city call is as follows: [3831208, 'qaanaaq', 77.484, -69.3632, -11.78, 93.0, 100.0, 4.74, 'GL', 1644345770].
# The data from the 84 city call is as follows: [1633419, 'padang', -0.9492, 100.3543, 75.25, 81.0, 100.0, 5.57, 'ID', 1644345770].
# The data from the 85 city call is as follows: [1510377, 'belyy yar', 53.6039, 91.3903, -4.11, 84.0, 72.0, 0, 'RU', 1644345770].
# The data from the 86 city call is as follows: [4031637, 'lavrentiya', 65.5833, -171, -26.52, 97.0, 37.0, 12.66, 'RU', 1644345771].
# The data from the 87 city call is as follows: [4034551, 'faanui', -16.4833, -151.75, 81.48, 78.0, 15.0, 20.29, 'PF', 1644345771].
# The data from the 88 city call is as follows: [2122090, 'pevek', 69.7008, 170.3133, -32.08, 100.0, 50.0, 5.37, 'RU', 1644345771].
# The data from the 89 city call is as follows: [2208248, 'kaitangata', -46.2817, 169.8464, 54.34, 95.0, 100.0, 5.91, 'NZ', 1644345772].
# The data from the 90 city call is as follows: [962367, 'richards bay', -28.783, 32.0377, 71.31, 88.0, 1.0, 2.37, 'ZA', 1644345772].
# Failed on 91 try.
# The data from the 92 city call is as follows: [5895424, 'bay roberts', 47.5999, -53.2648, 32.05, 74.0, 100.0, 3, 'CA', 1644345773].
# The data from the 93 city call is as follows: [2155415, 'new norfolk', -42.7826, 147.0587, 54.91, 72.0, 59.0, 1.72, 'AU', 1644345773].
# The data from the 94 city call is as follows: [3374166, 'tarrafal', 15.2833, -23.7667, 77.79, 77.0, 0.0, 13.62, 'CV', 1644345773].
# The data from the 95 city call is as follows: [292672, 'sharjah', 25.3573, 55.4033, 69.78, 56.0, 40.0, 6.91, 'AE', 1644345774].
# The data from the 96 city call is as follows: [964432, 'port alfred', -33.5906, 26.891, 74.1, 88.0, 4.0, 3.29, 'ZA', 1644345774].
# The data from the 97 city call is as follows: [107304, 'buraydah', 26.326, 43.975, 61.25, 29.0, 0.0, 9.06, 'SA', 1644345775].
# The data from the 98 city call is as follows: [2063042, 'port hedland', -20.3167, 118.5667, 78.85, 94.0, 26.0, 5.75, 'AU', 1644345775].
# Failed on 99 try.
# The data from the 100 city call is as follows: [3372964, 'lagoa', 39.05, -27.9833, 59.54, 71.0, 95.0, 6.02, 'PT', 1644345776].
# The data from the 101 city call is as follows: [1337619, 'ugoofaaru', 5.6667, 73, 82.42, 64.0, 86.0, 12.95, 'MV', 1644345776].
# The data from the 102 city call is as follows: [877747, 'mtwara', -10.2667, 40.1833, 79.39, 85.0, 100.0, 9.28, 'TZ', 1644345776].
# The data from the 103 city call is as follows: [6111862, 'port hardy', 50.6996, -127.4199, 44.76, 93.0, 100.0, 13.8, 'CA', 1644345736].
# The data from the 104 city call is as follows: [5557293, 'sitka', 57.0531, -135.33, 44.49, 81.0, 100.0, 13.8, 'US', 1644345777].
# The data from the 105 city call is as follows: [596664, 'nemencine', 54.85, 25.4833, 34.32, 98.0, 100.0, 13.76, 'LT', 1644345777].
# The data from the 106 city call is as follows: [3893629, 'coquimbo', -29.9533, -71.3436, 68.31, 73.0, 39.0, 7.56, 'CL', 1644345778].
# The data from the 107 city call is as follows: [1855612, 'nara', 34.6851, 135.8049, 36.97, 62.0, 100.0, 1.77, 'JP', 1644345778].
# The data from the 108 city call is as follows: [2985947, 'porto-vecchio', 41.591, 9.2795, 47.73, 87.0, 0.0, 4.61, 'FR', 1644345779].
# The data from the 109 city call is as follows: [2012646, 'zarubino', 42.63, 131.0922, 22.59, 66.0, 0.0, 8.66, 'RU', 1644345779].
# The data from the 110 city call is as follows: [1633034, 'liku', -0.7275, 119.8922, 74.46, 96.0, 100.0, 2.01, 'ID', 1644345779].
# The data from the 111 city call is as follows: [535639, 'letka', 59.6011, 49.4232, 14.29, 95.0, 90.0, 7.72, 'RU', 1644345780].
# The data from the 112 city call is as follows: [1643078, 'indramayu', -6.3264, 108.32, 78.51, 84.0, 100.0, 8.79, 'ID', 1644345780].
# The data from the 113 city call is as follows: [1621313, 'ambulu', -8.345, 113.6058, 75.38, 91.0, 61.0, 3.53, 'ID', 1644345781].
# The data from the 114 city call is as follows: [3902377, 'trinidad', -14.8333, -64.9, 89.58, 51.0, 75.0, 6.91, 'BO', 1644345781].
# The data from the 115 city call is as follows: [5961417, 'gimli', 50.6336, -96.9907, 36.43, 87.0, 100.0, 10.36, 'CA', 1644345781].
# The data from the 116 city call is as follows: [1692364, 'puro', 12.4841, 123.3827, 76.51, 80.0, 63.0, 10.6, 'PH', 1644345782].
# The data from the 117 city call is as follows: [5919850, 'chapais', 49.7834, -74.8492, 20.98, 87.0, 100.0, 7.14, 'CA', 1644345782].
# The data from the 118 city call is as follows: [3361934, 'saldanha', -33.0117, 17.9442, 68.05, 93.0, 15.0, 10.8, 'ZA', 1644345783].
# Failed on 119 try.
# The data from the 120 city call is as follows: [5983720, 'iqaluit', 63.7506, -68.5145, -0.31, 77.0, 100.0, 8.05, 'CA', 1644345783].
# The data from the 121 city call is as follows: [1007311, 'durban', -29.8579, 31.0292, 77.02, 83.0, 1.0, 1.01, 'ZA', 1644345518].
# The data from the 122 city call is as follows: [5733351, 'jackson', 42.4165, -122.8345, 57.15, 59.0, 0.0, 0, 'US', 1644345784].
# The data from the 123 city call is as follows: [2129868, 'iwanai', 42.9744, 140.5089, 25.72, 78.0, 100.0, 9.06, 'JP', 1644345784].
# The data from the 124 city call is as follows: [2669047, 'timra', 62.487, 17.3257, 31.68, 100.0, 0.0, 0, 'SE', 1644345785].
# The data from the 125 city call is as follows: [4787534, 'sterling', 39.0062, -77.4286, 49.33, 44.0, 20.0, 13.8, 'US', 1644345678].
# The data from the 126 city call is as follows: [3412093, 'vestmannaeyjar', 63.4427, -20.2734, 31.19, 100.0, 75.0, 14.97, 'IS', 1644345785].
# The data from the 127 city call is as follows: [3466980, 'caravelas', -17.7125, -39.2481, 83.86, 61.0, 99.0, 9.24, 'BR', 1644345786].
# The data from the 128 city call is as follows: [2173911, 'broken hill', -31.95, 141.4333, 67.71, 83.0, 75.0, 4.61, 'AU', 1644345786].
# The data from the 129 city call is as follows: [6180550, 'whitehorse', 60.7161, -135.0538, 27.37, 86.0, 75.0, 18.41, 'CA', 1644345786].
# Failed on 130 try.
# The data from the 131 city call is as follows: [3430443, 'necochea', -38.5473, -58.7368, 81.03, 44.0, 0.0, 7.02, 'AR', 1644345787].
# The data from the 132 city call is as follows: [519062, 'novoanninskiy', 50.5287, 42.6747, 33.57, 94.0, 100.0, 16.31, 'RU', 1644345788].
# The data from the 133 city call is as follows: [2206894, 'hokitika', -42.7167, 170.9667, 66.43, 91.0, 100.0, 2.3, 'NZ', 1644345789].
# The data from the 134 city call is as follows: [3449304, 'sao desiderio', -12.3633, -44.9733, 81.68, 70.0, 100.0, 2.06, 'BR', 1644345789].
# The data from the 135 city call is as follows: [4231997, 'avera', 33.194, -82.5271, 51.71, 42.0, 100.0, 6.42, 'US', 1644345790].
# The data from the 136 city call is as follows: [1061605, 'manakara', -22.1333, 48.0167, 78.64, 91.0, 100.0, 12.5, 'MG', 1644345790].
# The data from the 137 city call is as follows: [3404558, 'cabedelo', -6.9811, -34.8339, 86.67, 66.0, 2.0, 12.64, 'BR', 1644345498].
# The data from the 138 city call is as follows: [3471451, 'arraial do cabo', -22.9661, -42.0278, 73.36, 94.0, 75.0, 10.36, 'BR', 1644345791].
# Failed on 139 try.
# The data from the 140 city call is as follows: [2108502, 'honiara', -9.4333, 159.95, 78.06, 90.0, 100.0, 6.26, 'SB', 1644345791].
# The data from the 141 city call is as follows: [3893726, 'constitucion', -35.3333, -72.4167, 74.26, 54.0, 13.0, 18.81, 'CL', 1644345792].
# The data from the 142 city call is as follows: [3356832, 'henties bay', -22.116, 14.2845, 71.85, 81.0, 16.0, 4.92, 'NA', 1644345792].
# The data from the 143 city call is as follows: [3450909, 'rondonopolis', -16.4708, -54.6356, 83.68, 69.0, 80.0, 0.89, 'BR', 1644345712].
# The data from the 144 city call is as follows: [686090, 'asau', 46.4333, 26.4, 29.32, 89.0, 9.0, 5.01, 'RO', 1644345793].
# The data from the 145 city call is as follows: [1849892, 'tottori', 35.5, 134.2333, 39.25, 92.0, 100.0, 8.08, 'JP', 1644345555].
# The data from the 146 city call is as follows: [3385670, 'urucara', -2.5364, -57.76, 77.94, 91.0, 97.0, 3.11, 'BR', 1644345793].
# The data from the 147 city call is as follows: [5847411, 'kahului', 20.8947, -156.47, 75.85, 73.0, 20.0, 11.01, 'US', 1644345794].
# The data from the 148 city call is as follows: [3405051, 'borba', -4.3878, -59.5939, 85.69, 74.0, 96.0, 1.19, 'BR', 1644345794].
# The data from the 149 city call is as follows: [5546220, 'saint george', 37.1041, -113.5841, 62.35, 33.0, 0.0, 0, 'US', 1644345795].
# The data from the 150 city call is as follows: [3035768, 'avallon', 47.4833, 3.9, 41.5, 89.0, 31.0, 2.93, 'FR', 1644345621].
# The data from the 151 city call is as follows: [5905393, 'bonavista', 48.6499, -53.1147, 33.12, 76.0, 100.0, 12.57, 'CA', 1644345795].
# The data from the 152 city call is as follows: [6078372, 'moose factory', 51.2585, -80.6094, 17.6, 67.0, 0.0, 4.61, 'CA', 1644345796].
# Failed on 153 try.
# The data from the 154 city call is as follows: [5870133, 'nome', 64.5011, -165.4064, 1.47, 46.0, 100.0, 24.16, 'US', 1644345796].
# The data from the 155 city call is as follows: [902620, 'mwinilunga', -11.7358, 24.4293, 63.57, 95.0, 100.0, 3.96, 'ZM', 1644345796].
# The data from the 156 city call is as follows: [80509, 'bardiyah', 31.7561, 25.0865, 54.82, 59.0, 100.0, 23.11, 'LY', 1644345797].
# The data from the 157 city call is as follows: [3408269, 'afua', -0.1567, -50.3867, 83.17, 74.0, 96.0, 7.02, 'BR', 1644345797].
# The data from the 158 city call is as follows: [3652764, 'puerto ayora', -0.7393, -90.3518, 80.56, 69.0, 62.0, 10.71, 'EC', 1644345798].
# The data from the 159 city call is as follows: [2629833, 'husavik', 66.0449, -17.3389, 28.31, 93.0, 100.0, 24.14, 'IS', 1644345798].
# The data from the 160 city call is as follows: [3945985, 'camana', -16.6228, -72.7111, 74.89, 70.0, 94.0, 9.57, 'PE', 1644345798].
# The data from the 161 city call is as follows: [1503153, 'klyuchi', 52.2667, 79.1667, 10.36, 97.0, 93.0, 4.34, 'RU', 1644345799].
# The data from the 162 city call is as follows: [2245170, 'podor', 16.6527, -14.9587, 96.75, 14.0, 0.0, 2.3, 'MR', 1644345799].
# The data from the 163 city call is as follows: [103630, 'najran', 17.4924, 44.1277, 59.65, 32.0, 3.0, 2.93, 'SA', 1644345733].
# The data from the 164 city call is as follows: [2460954, 'araouane', 18.9048, -3.5265, 73.13, 8.0, 0.0, 9.69, 'ML', 1644345799].
# The data from the 165 city call is as follows: [1819729, 'victoria', 22.2855, 114.1577, 62.26, 84.0, 100.0, 5.99, 'HK', 1644345551].
# The data from the 166 city call is as follows: [5866583, 'kodiak', 57.79, -152.4072, 29.71, 69.0, 0.0, 11.5, 'US', 1644345800].
# The data from the 167 city call is as follows: [2039557, 'khasan', 42.4308, 130.6434, 24.71, 63.0, 0.0, 5.23, 'RU', 1644345800].
# The data from the 168 city call is as follows: [5416329, 'castle rock', 39.3722, -104.8561, 50.83, 35.0, 0.0, 8.99, 'US', 1644345801].
# The data from the 169 city call is as follows: [1246294, 'galle', 6.0367, 80.217, 78.33, 73.0, 100.0, 1.77, 'LK', 1644345801].
# Failed on 170 try.
# The data from the 171 city call is as follows: [1624725, 'tarakan', 3.3, 117.6333, 76.1, 87.0, 100.0, 6.73, 'ID', 1644345802].
# The data from the 172 city call is as follows: [2393693, 'kandi', 11.1342, 2.9386, 83.59, 13.0, 62.0, 5.19, 'BJ', 1644345802].
# Failed on 173 try.
# The data from the 174 city call is as follows: [1714733, 'dingle', 10.9995, 122.6711, 74.5, 90.0, 65.0, 9.46, 'PH', 1644345802].
# The data from the 175 city call is as follows: [6541341, 'porto empedocle', 37.2934, 13.5264, 51.04, 54.0, 1.0, 5.64, 'IT', 1644345803].
# The data from the 176 city call is as follows: [6089245, 'norman wells', 65.282, -126.8329, -27.36, 62.0, 75.0, 0, 'CA', 1644345803].
# The data from the 177 city call is as follows: [2662689, 'visby', 57.6409, 18.296, 39.06, 87.0, 0.0, 9.22, 'SE', 1644345804].
# The data from the 178 city call is as follows: [4726521, 'san patricio', 28.017, -97.5169, 66.29, 30.0, 0.0, 3.49, 'US', 1644345804].
# The data from the 179 city call is as follows: [4004293, 'ixtapa', 20.7, -105.2, 87.13, 30.0, 0.0, 7.56, 'MX', 1644345804].
# The data from the 180 city call is as follows: [778707, 'mehamn', 71.0357, 27.8492, 30.38, 74.0, 0.0, 35.68, 'NO', 1644345805].
# The data from the 181 city call is as follows: [3038333, 'ajaccio', 42, 8.9167, 42.85, 76.0, 0.0, 6.91, 'FR', 1644345805].
# The data from the 182 city call is as follows: [556268, 'ostrovnoy', 68.0531, 39.5131, 14.65, 89.0, 70.0, 14.97, 'RU', 1644345805].
# The data from the 183 city call is as follows: [3175096, 'lasa', 46.6166, 10.7002, 44.06, 60.0, 2.0, 6.4, 'IT', 1644345806].
# The data from the 184 city call is as follows: [3115824, 'muros', 42.7762, -9.0603, 59.5, 68.0, 6.0, 4.83, 'ES', 1644345806].
# The data from the 185 city call is as follows: [4513583, 'hamilton', 39.1834, -84.5333, 42.58, 58.0, 0.0, 9.22, 'US', 1644345670].
# The data from the 186 city call is as follows: [546105, 'nikolskoye', 59.7035, 30.7861, 30.09, 96.0, 100.0, 4.85, 'RU', 1644345807].
# The data from the 187 city call is as follows: [4392354, 'jasper', 37.2001, -94.3502, 58.26, 34.0, 0.0, 13.8, 'US', 1644345807].
# The data from the 188 city call is as follows: [2501152, 'constantine', 36.365, 6.6147, 45.81, 81.0, 40.0, 3.44, 'DZ', 1644345807].
# The data from the 189 city call is as follows: [2126199, 'cherskiy', 68.75, 161.3, -41.57, 100.0, 87.0, 4.41, 'RU', 1644345808].
# The data from the 190 city call is as follows: [1215502, 'banda aceh', 5.5577, 95.3222, 78.19, 84.0, 100.0, 6.22, 'ID', 1644345808].
# The data from the 191 city call is as follows: [3437653, 'nueva germania', -23.9, -56.5667, 91.51, 19.0, 0.0, 5.68, 'PY', 1644345808].
# The data from the 192 city call is as follows: [737021, 'zonguldak', 41.25, 31.8333, 37.62, 98.0, 100.0, 2.86, 'TR', 1644345809].
# The data from the 193 city call is as follows: [5262634, 'menomonie', 44.8755, -91.9193, 35.4, 64.0, 100.0, 4.61, 'US', 1644345552].
# The data from the 194 city call is as follows: [6316343, 'alta floresta', -9.8756, -56.0861, 82.22, 83.0, 40.0, 2.3, 'BR', 1644345810].
# The data from the 195 city call is as follows: [777019, 'vardo', 70.3705, 31.1107, 30.4, 69.0, 75.0, 23.02, 'NO', 1644345810].
# The data from the 196 city call is as follows: [2122614, 'okha', 53.5739, 142.9478, 15.84, 94.0, 100.0, 18.57, 'RU', 1644345811].
# The data from the 197 city call is as follows: [4946620, 'palmer', 42.1584, -72.3287, 43.41, 74.0, 75.0, 11.5, 'US', 1644345811].
# The data from the 198 city call is as follows: [3443061, 'chuy', -33.6971, -53.4616, 74.12, 52.0, 4.0, 11.59, 'UY', 1644345811].
# The data from the 199 city call is as follows: [2450173, 'taoudenni', 22.6783, -3.9836, 74.28, 10.0, 0.0, 11.21, 'ML', 1644345812].
# The data from the 200 city call is as follows: [305681, 'kumluca', 36.3703, 30.2869, 58.68, 85.0, 93.0, 12.48, 'TR', 1644345812].
# The data from the 201 city call is as follows: [172515, 'abu samrah', 35.3029, 37.1841, 50.67, 78.0, 87.0, 1.3, 'SY', 1644345812].
# The data from the 202 city call is as follows: [1516048, 'hovd', 48.0056, 91.6419, -11.69, 78.0, 13.0, 2.28, 'MN', 1644345813].
# The data from the 203 city call is as follows: [4174757, 'tampa', 27.9475, -82.4584, 55.42, 94.0, 100.0, 6.91, 'US', 1644345676].
# The data from the 204 city call is as follows: [2094027, 'kieta', -6.2167, 155.6333, 80.04, 85.0, 100.0, 6.93, 'PG', 1644345813].
# The data from the 205 city call is as follows: [1731298, 'aloleng', 16.1307, 119.7824, 77.41, 77.0, 100.0, 7.76, 'PH', 1644345813].
# The data from the 206 city call is as follows: [3516522, 'soto la marina', 23.7667, -98.2167, 64.78, 32.0, 27.0, 6.17, 'MX', 1644345814].
# The data from the 207 city call is as follows: [370737, 'malakal', 9.5334, 31.6605, 81.64, 20.0, 13.0, 5.3, 'SS', 1644345814].
# The data from the 208 city call is as follows: [5392171, 'san jose', 37.3394, -121.895, 70.09, 46.0, 20.0, 5.01, 'US', 1644345632].
# The data from the 209 city call is as follows: [3393536, 'olinda', -8.0089, -34.8553, 85.73, 62.0, 40.0, 9.22, 'BR', 1644345815].
# Failed on 210 try.
# The data from the 211 city call is as follows: [4031574, 'provideniya', 64.3833, -173.3, -14.82, 83.0, 1.0, 12.5, 'RU', 1644345815].
# The data from the 212 city call is as follows: [478050, 'ust-kulom', 61.6864, 53.6902, 5.7, 97.0, 90.0, 6.2, 'RU', 1644345815].
# The data from the 213 city call is as follows: [64814, 'bandarbeyla', 9.4942, 50.8122, 75.54, 66.0, 6.0, 17.16, 'SO', 1644345816].
# The data from the 214 city call is as follows: [292968, 'abu dhabi', 24.4667, 54.3667, 66.31, 61.0, 0.0, 9.22, 'AE', 1644345591].
# The data from the 215 city call is as follows: [1529195, 'shihezi', 44.3, 86.0333, 2.82, 95.0, 49.0, 3.78, 'CN', 1644345816].
# The data from the 216 city call is as follows: [2412408, 'nioro', 13.35, -15.75, 90.54, 8.0, 3.0, 6.76, 'GM', 1644345817].
# The data from the 217 city call is as follows: [6690296, 'saint-joseph', -21.3667, 55.6167, 75.58, 84.0, 40.0, 9.48, 'RE', 1644345817].
# The data from the 218 city call is as follows: [3521972, 'panaba', 21.2833, -88.2667, 72.64, 89.0, 99.0, 16.73, 'MX', 1644345818].
# The data from the 219 city call is as follows: [2013279, 'vostok', 46.4856, 135.8833, -3.57, 99.0, 100.0, 3.71, 'RU', 1644345818].
# The data from the 220 city call is as follows: [7671223, 'kloulklubed', 7.0419, 134.2556, 82.42, 81.0, 100.0, 19.13, 'PW', 1644345818].
# The data from the 221 city call is as follows: [2657126, 'ardrishaig', 56.0157, -5.4481, 46.29, 83.0, 100.0, 14.05, 'GB', 1644345819].
# The data from the 222 city call is as follows: [6096551, 'pangnirtung', 66.1451, -65.7125, -9.4, 70.0, 100.0, 5.75, 'CA', 1644345819].
# The data from the 223 city call is as follows: [3372707, 'ribeira grande', 38.5167, -28.7, 59.4, 82.0, 40.0, 3.44, 'PT', 1644345820].
# The data from the 224 city call is as follows: [3839307, 'rawson', -43.3002, -65.1023, 69.22, 54.0, 100.0, 20.47, 'AR', 1644345649].
# The data from the 225 city call is as follows: [5655240, 'great falls', 47.5002, -111.3008, 47.93, 29.0, 0.0, 23.02, 'US', 1644345676].
# The data from the 226 city call is as follows: [905789, 'mpongwe', -13.5091, 28.155, 64.6, 95.0, 98.0, 1.36, 'ZM', 1644345820].
# The data from the 227 city call is as follows: [4723422, 'rockport', 28.0206, -97.0544, 66.45, 35.0, 0.0, 6.91, 'US', 1644345803].
# The data from the 228 city call is as follows: [4001056, 'la orilla', 17.9833, -102.2333, 81.57, 59.0, 5.0, 9.6, 'MX', 1644345821].
# The data from the 229 city call is as follows: [1504382, 'kargasok', 59.0556, 80.8572, -15.32, 100.0, 6.0, 5.79, 'RU', 1644345821].
# The data from the 230 city call is as follows: [1244926, 'hambantota', 6.1241, 81.1185, 75.54, 94.0, 40.0, 5.75, 'LK', 1644345822].
# The data from the 231 city call is as follows: [5959335, 'gander', 48.9682, -54.5906, 32.16, 80.0, 100.0, 10.36, 'CA', 1644345822].
# The data from the 232 city call is as follows: [6067472, 'marystown', 47.1666, -55.1483, 36.86, 100.0, 100.0, 7, 'CA', 1644345822].
# The data from the 233 city call is as follows: [3146487, 'raudeberg', 61.9875, 5.1352, 40.19, 89.0, 100.0, 11.99, 'NO', 1644345823].
# The data from the 234 city call is as follows: [6145890, 'shelburne', 44.0787, -80.2041, 28.13, 76.0, 100.0, 12.71, 'CA', 1644345823].
# The data from the 235 city call is as follows: [1528998, 'yumen', 40.2833, 97.2, 18.5, 52.0, 11.0, 7.36, 'CN', 1644345823].
# The data from the 236 city call is as follows: [1494088, 'promyshlennyy', 67.5833, 63.9167, -9.06, 95.0, 100.0, 8.43, 'RU', 1644345824].
# The data from the 237 city call is as follows: [350203, 'rosetta', 31.4044, 30.4164, 60.62, 47.0, 99.0, 10.74, 'EG', 1644345824].
# The data from the 238 city call is as follows: [203717, 'yangambi', 0.8102, 24.4336, 76.69, 43.0, 21.0, 2.8, 'CD', 1644345825].
# The data from the 239 city call is as follows: [656820, 'iisalmi', 63.5592, 27.1907, 24.82, 95.0, 100.0, 6.82, 'FI', 1644345825].
# The data from the 240 city call is as follows: [3984997, 'san quintin', 30.4833, -115.95, 69.17, 22.0, 0.0, 3.69, 'MX', 1644345825].
# The data from the 241 city call is as follows: [2212775, 'sabha', 27.0377, 14.4283, 58.84, 29.0, 0.0, 12.3, 'LY', 1644345826].
# The data from the 242 city call is as follows: [5746545, 'portland', 45.5234, -122.6762, 50.38, 87.0, 100.0, 3.44, 'US', 1644345793].
# Failed on 243 try.
# The data from the 244 city call is as follows: [2128025, 'shizunai', 42.3339, 142.3669, 23.49, 76.0, 38.0, 9.69, 'JP', 1644345826].
# The data from the 245 city call is as follows: [3336897, 'la rioja', 42.25, -2.5, 47.32, 60.0, 10.0, 5.73, 'ES', 1644345778].
# The data from the 246 city call is as follows: [2122493, 'omsukchan', 62.5333, 155.8, -22.65, 72.0, 98.0, 2.82, 'RU', 1644345827].
# The data from the 247 city call is as follows: [1629974, 'rantepao', -2.9701, 119.8978, 67.71, 95.0, 100.0, 2.1, 'ID', 1644345827].
# The data from the 248 city call is as follows: [934479, 'grand gaube', -20.0064, 57.6608, 77.4, 78.0, 93.0, 11.45, 'MU', 1644345827].
# The data from the 249 city call is as follows: [6144312, 'sept-iles', 50.2001, -66.3821, 21.06, 85.0, 100.0, 14.97, 'CA', 1644345607].
# The data from the 250 city call is as follows: [6170031, 'tuktoyaktuk', 69.4541, -133.0374, -43.6, 66.0, 20.0, 5.75, 'CA', 1644345828].
# The data from the 251 city call is as follows: [3618337, 'rosita', 13.9268, -84.4032, 88.92, 34.0, 11.0, 4.9, 'NI', 1644345828].
# The data from the 252 city call is as follows: [3421982, 'maniitsoq', 65.4167, -52.9, -2.33, 86.0, 98.0, 17.63, 'GL', 1644345829].
# Failed on 253 try.
# The data from the 254 city call is as follows: [494846, 'shepsi', 44.0361, 39.1489, 49.24, 74.0, 100.0, 23.35, 'RU', 1644345829].
# The data from the 255 city call is as follows: [2128975, 'nemuro', 43.3236, 145.575, 23.76, 72.0, 60.0, 13.44, 'JP', 1644345830].
# The data from the 256 city call is as follows: [2168305, 'dubbo', -32.25, 148.6167, 53.73, 82.0, 11.0, 8.05, 'AU', 1644345830].
# The data from the 257 city call is as follows: [3448903, 'sao joao da barra', -21.6403, -41.0511, 77.09, 85.0, 58.0, 6.64, 'BR', 1644345814].
# The data from the 258 city call is as follows: [4031742, 'egvekinot', 66.3167, -179.1667, -15.9, 68.0, 0.0, 15.7, 'RU', 1644345830].
# The data from the 259 city call is as follows: [3517970, 'pochutla', 15.7432, -96.4661, 84.02, 49.0, 30.0, 7.56, 'MX', 1644345831].
# The data from the 260 city call is as follows: [1161724, 'chabahar', 25.2919, 60.643, 71.65, 60.0, 0.0, 7.78, 'IR', 1644345831].
# The data from the 261 city call is as follows: [930025, 'dedza', -14.3779, 34.3332, 59.47, 95.0, 73.0, 1.43, 'MW', 1644345832].
# The data from the 262 city call is as follows: [3374210, 'sao filipe', 14.8961, -24.4956, 73.24, 72.0, 0.0, 4.63, 'CV', 1644345832].
# The data from the 263 city call is as follows: [3347762, 'lubango', -14.9172, 13.4925, 61.05, 80.0, 100.0, 3.33, 'AO', 1644345832].
# The data from the 264 city call is as follows: [1224061, 'wattegama', 6.7989, 81.4808, 74.32, 77.0, 97.0, 5.5, 'LK', 1644345833].
# The data from the 265 city call is as follows: [5563839, 'fortuna', 40.5982, -124.1573, 53.98, 89.0, 0.0, 0, 'US', 1644345833].
# The data from the 266 city call is as follows: [2126710, 'beringovskiy', 63.05, 179.3167, -21.98, 91.0, 5.0, 12.26, 'RU', 1644345834].
# The data from the 267 city call is as follows: [1062553, 'mahanoro', -19.9, 48.8, 79.21, 91.0, 100.0, 8.9, 'MG', 1644345834].
# The data from the 268 city call is as follows: [3137469, 'sorland', 67.667, 12.6934, 39.06, 60.0, 100.0, 30.96, 'NO', 1644345835].
# The data from the 269 city call is as follows: [3374083, 'bathsheba', 13.2167, -59.5167, 83.01, 54.0, 40.0, 17.27, 'BB', 1644345835].
# The data from the 270 city call is as follows: [935215, 'saint-philippe', -21.3585, 55.7679, 76.59, 84.0, 44.0, 9.06, 'RE', 1644345835].
# The data from the 271 city call is as follows: [1701394, 'manuk mangkaw', 4.8, 119.85, 80.28, 79.0, 100.0, 6.24, 'PH', 1644345836].
# The data from the 272 city call is as follows: [964420, 'port elizabeth', -33.918, 25.5701, 64.69, 88.0, 0.0, 6.91, 'ZA', 1644345836].
# The data from the 273 city call is as follows: [570479, 'khalimbekaul', 42.846, 47.1387, 34.68, 71.0, 100.0, 6.46, 'RU', 1644345836].
# Failed on 274 try.
# The data from the 275 city call is as follows: [2109528, 'buala', -8.145, 159.5921, 80.26, 83.0, 100.0, 10.13, 'SB', 1644345571].
# The data from the 276 city call is as follows: [3526756, 'isla mujeres', 21.2311, -86.731, 82.45, 60.0, 83.0, 8.97, 'MX', 1644345837].
# The data from the 277 city call is as follows: [3414079, 'olafsvik', 64.8945, -23.7142, 30.74, 78.0, 98.0, 37.56, 'IS', 1644345837].
# The data from the 278 city call is as follows: [3449467, 'santo estevao', -12.4303, -39.2514, 94.89, 29.0, 100.0, 12.06, 'BR', 1644345838].
# The data from the 279 city call is as follows: [2019323, 'nerchinskiy zavod', 51.3088, 119.61, -11.94, 100.0, 94.0, 2.82, 'RU', 1644345838].
# The data from the 280 city call is as follows: [2240449, 'luanda', -8.8368, 13.2343, 78.8, 73.0, 20.0, 10.36, 'AO', 1644345717].
# The data from the 281 city call is as follows: [1842966, 'kijang', 35.2442, 129.2139, 29.93, 43.0, 100.0, 6.73, 'KR', 1644345839].
# The data from the 282 city call is as follows: [650769, 'kristiinankaupunki', 62.2743, 21.376, 26.65, 92.0, 9.0, 7.63, 'FI', 1644345839].
# The data from the 283 city call is as follows: [1215350, 'bireun', 5.203, 96.7009, 76.48, 86.0, 100.0, 5.95, 'ID', 1644345840].
# The data from the 284 city call is as follows: [5970873, 'hare bay', 48.8499, -54.0148, 33.19, 72.0, 100.0, 10, 'CA', 1644345840].
# The data from the 285 city call is as follows: [4315535, 'bastrop', 32.7562, -91.8724, 59.43, 34.0, 0.0, 3, 'US', 1644345840].
# The data from the 286 city call is as follows: [2618795, 'klaksvik', 62.2266, -6.589, 34.72, 72.0, 97.0, 39.88, 'FO', 1644345841].
# The data from the 287 city call is as follows: [1848976, 'wajima', 37.4, 136.9, 36.5, 67.0, 87.0, 8.46, 'JP', 1644345841].
# The data from the 288 city call is as follows: [2214432, 'nalut', 30.3333, 10.85, 52.05, 65.0, 0.0, 16.13, 'LY', 1644345842].
# The data from the 289 city call is as follows: [935221, 'saint-paul', -21.0096, 55.2707, 77.11, 87.0, 64.0, 1.19, 'RE', 1644345842].
# The data from the 290 city call is as follows: [1529376, 'korla', 41.7597, 86.1469, 24.75, 49.0, 61.0, 2.59, 'CN', 1644345842].
# The data from the 291 city call is as follows: [2036892, 'hohhot', 40.8106, 111.6522, 12.49, 48.0, 0.0, 6.71, 'CN', 1644345677].
# The data from the 292 city call is as follows: [2270385, 'camacha', 33.0833, -16.3333, 63.36, 82.0, 0.0, 11.5, 'PT', 1644345843].
# The data from the 293 city call is as follows: [3832899, 'viedma', -40.8135, -62.9967, 91.18, 20.0, 96.0, 7.07, 'AR', 1644345843].
# The data from the 294 city call is as follows: [4034496, 'fare', -16.7, -151.0167, 81.5, 76.0, 100.0, 20, 'PF', 1644345844].
# The data from the 295 city call is as follows: [3419842, 'sisimiut', 66.9395, -53.6735, -3.59, 77.0, 100.0, 19.26, 'GL', 1644345844].
# The data from the 296 city call is as follows: [2015306, 'tiksi', 71.6872, 128.8694, -22.36, 99.0, 59.0, 8.05, 'RU', 1644345844].
# The data from the 297 city call is as follows: [1061335, 'mananjary', -21.2167, 48.3333, 78.75, 92.0, 100.0, 11.52, 'MG', 1644345845].
# The data from the 298 city call is as follows: [3405215, 'bonfim', 3.0833, -59.95, 93.15, 31.0, 100.0, 6.55, 'BR', 1644345845].
# The data from the 299 city call is as follows: [4036284, 'alofi', -19.0595, -169.9187, 73.29, 94.0, 100.0, 6.91, 'NU', 1644345846].
# The data from the 300 city call is as follows: [3489657, 'lucea', 18.451, -78.1736, 80.85, 72.0, 25.0, 1.14, 'JM', 1644345846].
# The data from the 301 city call is as follows: [5353775, 'grass valley', 39.2191, -121.0611, 69.8, 24.0, 0.0, 5.01, 'US', 1644345846].
# The data from the 302 city call is as follows: [5563397, 'eureka', 40.8021, -124.1637, 54.25, 82.0, 0.0, 1.01, 'US', 1644345847].
# The data from the 303 city call is as follows: [3698304, 'chimbote', -9.0853, -78.5783, 76.62, 64.0, 38.0, 11.18, 'PE', 1644345847].
# The data from the 304 city call is as follows: [3933104, 'pangoa', -12.1167, -73, 80.28, 66.0, 58.0, 3.98, 'PE', 1644345847].
# The data from the 305 city call is as follows: [2027042, 'batagay-alyta', 67.8006, 130.4114, -32.87, 97.0, 62.0, 4.25, 'RU', 1644345848].
# The data from the 306 city call is as follows: [3394023, 'natal', -5.795, -35.2094, 88.45, 58.0, 20.0, 13.8, 'BR', 1644345848].
# The data from the 307 city call is as follows: [2206874, 'waipawa', -41.4122, 175.5153, 60.46, 94.0, 100.0, 5.21, 'NZ', 1644345849].
# The data from the 308 city call is as follows: [4260977, 'marion', 39.7684, -86.1555, 40.78, 58.0, 0.0, 9.22, 'US', 1644345727].
# The data from the 309 city call is as follows: [5374920, 'morro bay', 35.3658, -120.8499, 75.33, 39.0, 5.0, 1.99, 'US', 1644345821].
# The data from the 310 city call is as follows: [1529484, 'hami', 42.8, 93.45, 25.18, 40.0, 0.0, 3.94, 'CN', 1644345852].
# The data from the 311 city call is as follows: [1487332, 'verkhnyaya inta', 65.9811, 60.3094, -4.92, 89.0, 100.0, 4.23, 'RU', 1644345852].
# The data from the 312 city call is as follows: [2100933, 'ambunti', -4.2365, 142.8448, 72.72, 99.0, 88.0, 1.28, 'PG', 1644345853].
# The data from the 313 city call is as follows: [2180815, 'tuatapere', -46.1333, 167.6833, 47.82, 92.0, 88.0, 4.25, 'NZ', 1644345853].
# The data from the 314 city call is as follows: [3533462, 'acapulco', 16.8634, -99.8901, 85.82, 62.0, 40.0, 9.22, 'MX', 1644345652].
# The data from the 315 city call is as follows: [1880252, 'pasir gudang', 1.4584, 103.8805, 79, 83.0, 75.0, 5.75, 'MY', 1644345853].
# The data from the 316 city call is as follows: [1276067, 'bhatkal', 13.9667, 74.5667, 73.98, 85.0, 77.0, 7.83, 'IN', 1644345854].
# The data from the 317 city call is as follows: [3576994, 'cockburn town', 21.4612, -71.1419, 82.36, 57.0, 40.0, 11.5, 'TC', 1644345854].
# The data from the 318 city call is as follows: [4741752, 'wichita falls', 33.9137, -98.4934, 64.17, 28.0, 0.0, 13.8, 'US', 1644345854].
# The data from the 319 city call is as follows: [1268761, 'junnar', 19.2, 73.8833, 59.63, 84.0, 85.0, 5.01, 'IN', 1644345855].
# The data from the 320 city call is as follows: [2216645, 'hun', 29.1268, 15.9477, 56.3, 57.0, 28.0, 8.23, 'LY', 1644345856].
# The data from the 321 city call is as follows: [486874, 'suda', 59.1525, 37.5582, 32.11, 98.0, 100.0, 6.6, 'RU', 1644345856].
# The data from the 322 city call is as follows: [3530599, 'carmen', 18.6333, -91.8333, 71.38, 84.0, 100.0, 27.65, 'MX', 1644345856].
# The data from the 323 city call is as follows: [2119283, 'zyryanka', 65.75, 150.85, -46.08, 100.0, 65.0, 4.36, 'RU', 1644345857].
# The data from the 324 city call is as follows: [1106677, 'bambous virieux', -20.3428, 57.7575, 77.25, 83.0, 40.0, 3.44, 'MU', 1644345857].
# Failed on 325 try.
# The data from the 326 city call is as follows: [4205615, 'liberty', 31.8335, -81.5004, 53.02, 57.0, 40.0, 5.75, 'US', 1644345858].
# The data from the 327 city call is as follows: [2125906, 'dukat', 62.55, 155.55, -20.42, 67.0, 99.0, 2.57, 'RU', 1644345858].
# The data from the 328 city call is as follows: [2445704, 'diffa', 13.3154, 12.6113, 72.39, 9.0, 52.0, 7.4, 'NE', 1644345859].
# The data from the 329 city call is as follows: [3939761, 'hualmay', -11.0964, -77.6139, 75.27, 68.0, 34.0, 9.15, 'PE', 1644345859].
# The data from the 330 city call is as follows: [5703673, 'elko', 41.0002, -115.5012, 43.05, 62.0, 0.0, 4, 'US', 1644345859].
# The data from the 331 city call is as follows: [2123814, 'leningradskiy', 69.3833, 178.4167, -27.4, 80.0, 11.0, 3.24, 'RU', 1644345860].
# The data from the 332 city call is as follows: [916668, 'isoka', -10.1606, 32.6335, 64.87, 92.0, 100.0, 1.5, 'ZM', 1644345860].
# Failed on 333 try.
# The data from the 334 city call is as follows: [2381334, 'atar', 20.5169, -13.0499, 86.05, 17.0, 92.0, 4.61, 'MR', 1644345861].
# Failed on 335 try.
# The data from the 336 city call is as follows: [2063039, 'port keats', -14.25, 129.55, 80.24, 84.0, 100.0, 3, 'AU', 1644345861].
# The data from the 337 city call is as follows: [2122605, 'okhotsk', 59.3833, 143.3, 7.97, 85.0, 100.0, 7, 'RU', 1644345862].
# The data from the 338 city call is as follows: [2441447, 'maine-soroa', 13.2114, 12.0241, 71.96, 10.0, 88.0, 8.9, 'NE', 1644345862].
# Failed on 339 try.
# The data from the 340 city call is as follows: [473903, 'vetluzhskiy', 58.3902, 45.4654, 26.74, 97.0, 100.0, 7.47, 'RU', 1644345863].
# The data from the 341 city call is as follows: [513898, 'pella', 59.7775, 30.8181, 30.25, 96.0, 100.0, 4.81, 'RU', 1644345863].
# The data from the 342 city call is as follows: [4956335, 'yarmouth', 41.7057, -70.2286, 42.19, 96.0, 100.0, 9.22, 'US', 1644345863].
# The data from the 343 city call is as follows: [1852357, 'shimoda', 34.6667, 138.95, 40.1, 70.0, 88.0, 14.67, 'JP', 1644345864].
# Failed on 344 try.
# The data from the 345 city call is as follows: [1071296, 'antalaha', -14.9003, 50.2788, 76.57, 90.0, 100.0, 4.92, 'MG', 1644345864].
# Failed on 346 try.
# The data from the 347 city call is as follows: [2016307, 'solnechnyy', 50.7214, 136.6319, -3.62, 97.0, 93.0, 3.33, 'RU', 1644345865].
# The data from the 348 city call is as follows: [522260, 'nikel', 69.4128, 30.222, 24.98, 98.0, 58.0, 5.93, 'RU', 1644345865].
# The data from the 349 city call is as follows: [3444105, 'san matias', -16.3667, -58.4, 84.72, 70.0, 88.0, 2.1, 'BO', 1644345866].
# The data from the 350 city call is as follows: [3491161, 'bull savanna', 17.8868, -77.5902, 79.99, 63.0, 31.0, 12.19, 'JM', 1644345866].
# The data from the 351 city call is as follows: [3393106, 'paragominas', -2.9667, -47.4833, 81.7, 81.0, 92.0, 3.58, 'BR', 1644345866].
# The data from the 352 city call is as follows: [4021858, 'guerrero negro', 27.9769, -114.0611, 71.49, 23.0, 95.0, 2.01, 'MX', 1644345867].
# Failed on 353 try.
# The data from the 354 city call is as follows: [564579, 'dubovyy umet', 52.9763, 50.2857, 22.89, 90.0, 100.0, 10.31, 'RU', 1644345867].
# The data from the 355 city call is as follows: [2090021, 'namatanai', -3.6667, 152.4333, 79.21, 82.0, 100.0, 3.24, 'PG', 1644345867].
# The data from the 356 city call is as follows: [2312888, 'mbanza-ngungu', -5.25, 14.8667, 69.76, 91.0, 11.0, 3.71, 'CD', 1644345868].
# The data from the 357 city call is as follows: [2013639, 'verkhnevilyuysk', 63.4453, 120.3167, -28.84, 100.0, 100.0, 2.59, 'RU', 1644345868].
# The data from the 358 city call is as follows: [1282027, 'male', 4.1748, 73.5089, 84.15, 74.0, 75.0, 8.05, 'MV', 1644345577].
# The data from the 359 city call is as follows: [4160812, 'key west', 24.5557, -81.7826, 84.2, 61.0, 0.0, 11.5, 'US', 1644345796].
# Failed on 360 try.
# Failed on 361 try.
# The data from the 362 city call is as follows: [3996426, 'matamoros', 25.5333, -103.25, 55.04, 32.0, 0.0, 2.64, 'MX', 1644345869].
# The data from the 363 city call is as follows: [2017155, 'saskylakh', 71.9167, 114.0833, -0.67, 86.0, 100.0, 13.38, 'RU', 1644345869].
# The data from the 364 city call is as follows: [370510, 'marabba', 12.35, 32.1833, 79.52, 17.0, 42.0, 9.53, 'SD', 1644345870].
# Failed on 365 try.
# The data from the 366 city call is as follows: [6171633, 'ucluelet', 48.9329, -125.5528, 44.1, 93.0, 100.0, 4.36, 'CA', 1644345584].
# The data from the 367 city call is as follows: [2126682, 'bilibino', 68.0546, 166.4372, -25.42, 73.0, 15.0, 2.21, 'RU', 1644345870].
# The data from the 368 city call is as follows: [2191562, 'dunedin', -45.8742, 170.5036, 57.79, 89.0, 100.0, 3, 'NZ', 1644345870].
# The data from the 369 city call is as follows: [3374333, 'praya', 14.9215, -23.5087, 77.54, 57.0, 0.0, 17.27, 'CV', 1644345871].
# The data from the 370 city call is as follows: [3573374, 'the valley', 18.217, -63.0578, 84.06, 57.0, 20.0, 12.66, 'AI', 1644345871].
# The data from the 371 city call is as follows: [1817858, 'babu', 24.4167, 111.5167, 40.33, 92.0, 100.0, 4.32, 'CN', 1644345872].
# The data from the 372 city call is as follows: [2121385, 'severo-kurilsk', 50.6789, 156.125, 30.78, 94.0, 94.0, 26.42, 'RU', 1644345872].
# The data from the 373 city call is as follows: [1650527, 'balikpapan', -1.2675, 116.8289, 76.19, 94.0, 75.0, 2.3, 'ID', 1644345872].
# The data from the 374 city call is as follows: [1503037, 'kodinsk', 58.6881, 99.1844, -23.76, 100.0, 77.0, 3.04, 'RU', 1644345873].
# The data from the 375 city call is as follows: [6071900, 'melita', 49.2681, -100.9967, 37.96, 81.0, 55.0, 21.23, 'CA', 1644345873].
# Failed on 376 try.
# The data from the 377 city call is as follows: [5126209, 'mastic beach', 40.7668, -72.8521, 48.97, 69.0, 0.0, 10.36, 'US', 1644345874].
# Failed on 378 try.
# The data from the 379 city call is as follows: [1649150, 'bengkulu', -3.8004, 102.2655, 76.03, 86.0, 100.0, 5.32, 'ID', 1644345875].
# The data from the 380 city call is as follows: [2337680, 'illela', 13.7292, 5.2975, 78.96, 11.0, 3.0, 10.07, 'NG', 1644345875].
# The data from the 381 city call is as follows: [373141, 'kaduqli', 11.0167, 29.7167, 77.32, 15.0, 100.0, 6.42, 'SD', 1644345876].
# The data from the 382 city call is as follows: [2158767, 'mareeba', -17, 145.4333, 70.52, 94.0, 32.0, 2.62, 'AU', 1644345876].
# The data from the 383 city call is as follows: [1492948, 'saryg-sep', 51.5, 95.6, -9.78, 100.0, 99.0, 1.92, 'RU', 1644345876].
# The data from the 384 city call is as follows: [2012956, 'yerbogachen', 61.2767, 108.0108, -15.05, 97.0, 100.0, 5.41, 'RU', 1644345877].
# The data from the 385 city call is as follows: [3915350, 'guayaramerin', -10.8368, -65.3614, 89.65, 58.0, 75.0, 10.36, 'BO', 1644345877].
# The data from the 386 city call is as follows: [86049, 'jalu', 29.0331, 21.5482, 59.65, 60.0, 0.0, 13.85, 'LY', 1644345878].
# The data from the 387 city call is as follows: [5367788, 'lompoc', 34.6391, -120.4579, 76.14, 47.0, 0.0, 1.99, 'US', 1644345604].
# The data from the 388 city call is as follows: [2160517, 'launceston', -41.45, 147.1667, 55.15, 88.0, 73.0, 1.14, 'AU', 1644345681].
# The data from the 389 city call is as follows: [1259412, 'ponnampet', 12.15, 75.9333, 63.14, 94.0, 24.0, 1.86, 'IN', 1644345878].
# The data from the 390 city call is as follows: [5262680, 'merrill', 45.1805, -89.6835, 35.11, 59.0, 0.0, 5.75, 'US', 1644345879].
# The data from the 391 city call is as follows: [3397967, 'itaituba', -4.2761, -55.9836, 91.56, 62.0, 40.0, 5.75, 'BR', 1644345879].
# ...
# The data from the 442 city call is as follows: [3865086, 'bahia blanca', -38.7196, -62.2724, 86.05, 24.0, 44.0, 5.68, 'AR', 1644345609].
# The data from the 443 city call is as follows: [5374376, 'monterey', 36.2505, -121.2516, 62.1, 33.0, 0.0, 2.3, 'US', 1644345845].
# The data from the 444 city call is as follows: [3929493, 'san juan bautista', -14.0108, -75.7358, 71.17, 38.0, 87.0, 14, 'PE', 1644345896].
# The data from the 445 city call is as follows: [1812256, 'dongsheng', 39.8161, 109.9776, 17.87, 67.0, 6.0, 8.5, 'CN', 1644345896].
# The data from the 446 city call is as follows: [5392593, 'san ramon', 37.7799, -121.978, 67.6, 49.0, 0.0, 4, 'US', 1644345897].
# The data from the 447 city call is as follows: [2460489, 'bandiagara', 14.3501, -3.6104, 88.23, 9.0, 0.0, 9.26, 'ML', 1644345897].
# The data from the 448 city call is as follows: [3625346, 'villa bruzual', 9.3328, -69.1208, 90.19, 46.0, 94.0, 1.52, 'VE', 1644345898].
# The data from the 449 city call is as follows: [6620339, 'karratha', -20.7377, 116.8463, 82.94, 76.0, 95.0, 9.6, 'AU', 1644345898].
# The data from the 450 city call is as follows: [3985710, 'cabo san lucas', 22.8909, -109.9124, 81.61, 52.0, 0.0, 6.91, 'MX', 1644345898].
# The data from the 451 city call is as follows: [1516589, 'zhezkazgan', 47.8043, 67.7144, 21.06, 96.0, 100.0, 9.78, 'KZ', 1644345899].
# The data from the 452 city call is as follows: [1242110, 'kalmunai', 7.4167, 81.8167, 76.96, 70.0, 100.0, 8.84, 'LK', 1644345899].
# The data from the 453 city call is as follows: [2070998, 'geraldton', -28.7667, 114.6, 66.61, 77.0, 0.0, 18.41, 'AU', 1644345899].
# The data from the 454 city call is as follows: [1626542, 'sorong', -0.8833, 131.25, 78.33, 85.0, 100.0, 7.16, 'ID', 1644345900].
# The data from the 455 city call is as follows: [2092164, 'lorengau', -2.0226, 147.2712, 81.25, 82.0, 100.0, 9.19, 'PG', 1644345901].
# Failed on 456 try.
# The data from the 457 city call is as follows: [2120400, 'tungor', 53.3808, 142.9564, 14.97, 94.0, 100.0, 19.39, 'RU', 1644345903].
# The data from the 458 city call is as follows: [1518296, 'tekeli', 44.83, 78.8239, 22.46, 77.0, 100.0, 6.51, 'KZ', 1644345676].
# The data from the 459 city call is as follows: [6065262, 'maniwaki', 46.3834, -75.966, 28.78, 86.0, 100.0, 1.14, 'CA', 1644345904].
# The data from the 460 city call is as follows: [2012530, 'zhigansk', 66.7697, 123.3711, -37.23, 100.0, 97.0, 5.48, 'RU', 1644345904].
# The data from the 461 city call is as follows: [1648636, 'bitung', 1.4451, 125.1824, 76.05, 89.0, 100.0, 6.26, 'ID', 1644345905].
# The data from the 462 city call is as follows: [286245, 'sur', 22.5667, 59.5289, 70.36, 53.0, 0.0, 11.34, 'OM', 1644345905].
# Failed on 463 try.
# The data from the 464 city call is as follows: [1540711, 'muravlenko', 63.7898, 74.523, -9, 91.0, 36.0, 11.81, 'RU', 1644345906].
# The data from the 465 city call is as follows: [1830377, 'lumphat', 13.4878, 106.9816, 75.85, 72.0, 15.0, 7.9, 'KH', 1644345906].
# The data from the 466 city call is as follows: [5296802, 'green valley', 31.8543, -110.9937, 66.31, 19.0, 0.0, 1.01, 'US', 1644345789].
# The data from the 467 city call is as follows: [110690, 'faya', 18.3851, 42.4509, 57.31, 67.0, 27.0, 2.59, 'SA', 1644345907].
# The data from the 468 city call is as follows: [3361142, 'springbok', -29.6643, 17.8865, 78.6, 25.0, 0.0, 6.11, 'ZA', 1644345907].
# Failed on 469 try.
# The data from the 470 city call is as follows: [2015913, 'suntar', 62.1444, 117.6319, -13.77, 98.0, 100.0, 4.23, 'RU', 1644345908].
# The data from the 471 city call is as follows: [515879, 'oktyabrskiy', 54.4815, 53.471, 13.62, 97.0, 100.0, 3.62, 'RU', 1644345908].
# The data from the 472 city call is as follows: [2142316, 'yeppoon', -23.1333, 150.7333, 69.58, 77.0, 19.0, 6.15, 'AU', 1644345908].
# The data from the 473 city call is as follows: [1798425, 'puyang', 29.4603, 119.8861, 39.43, 97.0, 100.0, 2.66, 'CN', 1644345909].
# The data from the 474 city call is as follows: [986717, 'kruisfontein', -34.0033, 24.7314, 68.34, 64.0, 0.0, 2.08, 'ZA', 1644345909].
# Failed on 475 try.
# Failed on 476 try.
# The data from the 477 city call is as follows: [2014078, 'urusha', 54.05, 122.9, 2.68, 89.0, 100.0, 7.02, 'RU', 1644345910].
# The data from the 478 city call is as follows: [2020584, 'magistralnyy', 56.1725, 107.4458, -4.41, 99.0, 100.0, 3.15, 'RU', 1644345910].
# The data from the 479 city call is as follows: [2059470, 'victor harbor', -35.5667, 138.6167, 66.29, 90.0, 0.0, 6.08, 'AU', 1644345910].
# The data from the 480 city call is as follows: [3556437, 'agramonte', 22.6786, -81.1156, 84.63, 32.0, 0.0, 2.08, 'CU', 1644345911].
# The data from the 481 city call is as follows: [1283217, 'khandbari', 27.3747, 87.2039, 49.32, 80.0, 61.0, 1.23, 'NP', 1644345911].
# The data from the 482 city call is as follows: [1651810, 'airai', -8.9266, 125.4092, 60.6, 96.0, 100.0, 1.45, 'TL', 1644345911].
# The data from the 483 city call is as follows: [2063036, 'port lincoln', -34.7333, 135.8667, 65.62, 76.0, 100.0, 9.44, 'AU', 1644345912].
# The data from the 484 city call is as follows: [2281120, 'tabou', 4.423, -7.3528, 79.59, 82.0, 5.0, 8.34, 'CI', 1644345912].
# The data from the 485 city call is as follows: [780643, 'bjornevatn', 69.6672, 29.9847, 29.82, 80.0, 75.0, 12.66, 'NO', 1644345912].
# The data from the 486 city call is as follows: [1488206, 'ust-ishim', 57.6935, 71.1665, 3.16, 97.0, 86.0, 5.19, 'RU', 1644345913].
# The data from the 487 city call is as follows: [1079048, 'ambovombe', -25.1667, 46.0833, 79.18, 72.0, 100.0, 12.59, 'MG', 1644345913].
# The data from the 488 city call is as follows: [2120612, 'tigil', 57.8, 158.6667, -4.7, 92.0, 58.0, 3.02, 'RU', 1644345913].
# Failed on 489 try.
# The data from the 490 city call is as follows: [1254046, 'tura', 25.5198, 90.2201, 54.25, 75.0, 4.0, 3.2, 'IN', 1644345914].
# The data from the 491 city call is as follows: [2026160, 'borogontsy', 62.6683, 131.1683, -30.68, 100.0, 100.0, 0.96, 'RU', 1644345914].
# The data from the 492 city call is as follows: [1072849, 'ankazobe', -18.3167, 47.1167, 72.01, 93.0, 100.0, 3.11, 'MG', 1644345914].
# Failed on 493 try.
# The data from the 494 city call is as follows: [1529102, 'urumqi', 43.801, 87.6005, 2.35, 85.0, 29.0, 2.24, 'CN', 1644345915].
# The data from the 495 city call is as follows: [6165406, 'thompson', 55.7435, -97.8558, 21.36, 86.0, 100.0, 12.66, 'CA', 1644345915].
# The data from the 496 city call is as follows: [3139516, 'sjovegan', 68.8726, 17.8474, 34.03, 88.0, 88.0, 8.88, 'NO', 1644345915].
# The data from the 497 city call is as follows: [1176608, 'islamkot', 24.6997, 70.177, 72.82, 53.0, 77.0, 8.52, 'PK', 1644345916].
# The data from the 498 city call is as follows: [3141667, 'roald', 62.5833, 6.1333, 41, 87.0, 75.0, 23.02, 'NO', 1644345916].
# The data from the 499 city call is as follows: [5117949, 'freeport', 40.6576, -73.5832, 48.16, 56.0, 0.0, 13.8, 'US', 1644345913].
# The data from the 500 city call is as follows: [1259986, 'pedana', 16.2667, 81.1667, 73.2, 78.0, 84.0, 7.99, 'IN', 1644345917].
# The data from the 501 city call is as follows: [2025256, 'chumikan', 54.7183, 135.315, -2.34, 92.0, 100.0, 13.04, 'RU', 1644345917].
# The data from the 502 city call is as follows: [2090990, 'mendi', -6.1761, 143.6513, 54.3, 97.0, 92.0, 3.06, 'PG', 1644345917].
# The data from the 503 city call is as follows: [3681563, 'guamo', 4.0308, -74.9701, 76.62, 64.0, 88.0, 3.31, 'CO', 1644345918].
# The data from the 504 city call is as follows: [3395981, 'maceio', -9.6658, -35.7353, 89.04, 51.0, 20.0, 14.97, 'BR', 1644345836].
# The data from the 505 city call is as follows: [3948448, 'acolla', -11.7319, -75.5463, 59.65, 55.0, 100.0, 7.58, 'PE', 1644345918].
# The data from the 506 city call is as follows: [2145110, 'wagga wagga', -35.1167, 147.3667, 61.84, 82.0, 14.0, 8.05, 'AU', 1644345918].
# Failed on 507 try.
# The data from the 508 city call is as follows: [3386213, 'touros', -5.1989, -35.4608, 88.7, 59.0, 5.0, 16.22, 'BR', 1644345919].
# The data from the 509 city call is as follows: [493795, 'shonguy', 68.7526, 33.146, 21.27, 93.0, 40.0, 6.71, 'RU', 1644345919].
# The data from the 510 city call is as follows: [1259385, 'port blair', 11.6667, 92.75, 78.84, 78.0, 40.0, 9.22, 'IN', 1644345919].
# The data from the 511 city call is as follows: [3430545, 'moron', -34.6534, -58.6198, 79.95, 50.0, 0.0, 6.78, 'AR', 1644345920].
# The data from the 512 city call is as follows: [3580477, 'west bay', 19.3667, -81.4167, 83.07, 81.0, 40.0, 8.05, 'KY', 1644345920].
# The data from the 513 city call is as follows: [2409914, 'bonthe', 7.5264, -12.505, 80.94, 74.0, 55.0, 11.21, 'SL', 1644345921].
# The data from the 514 city call is as follows: [2181625, 'te anau', -45.4167, 167.7167, 55.8, 88.0, 100.0, 2.21, 'NZ', 1644345921].
# The data from the 515 city call is as follows: [5915327, 'cap-aux-meules', 47.3821, -61.8597, 32.05, 100.0, 100.0, 19.57, 'CA', 1644345921].
# The data from the 516 city call is as follows: [689736, 'vesele', 47.0148, 34.915, 35.64, 97.0, 100.0, 12.35, 'UA', 1644345922].
# The data from the 517 city call is as follows: [49747, 'xuddur', 4.1213, 43.8894, 76.93, 23.0, 58.0, 12.21, 'SO', 1644345922].
# The data from the 518 city call is as follows: [2156825, 'morwell', -38.2333, 146.4, 64.4, 98.0, 37.0, 2.48, 'AU', 1644345922].
# The data from the 519 city call is as follows: [3449747, 'santa vitoria do palmar', -33.5189, -53.3681, 74.7, 50.0, 1.0, 10.85, 'BR', 1644345923].
# The data from the 520 city call is as follows: [1053384, 'toamasina', -18.1667, 49.3833, 80.6, 89.0, 40.0, 4.61, 'MG', 1644345923].
# The data from the 521 city call is as follows: [780687, 'berlevag', 70.8578, 29.0864, 26.6, 74.0, 40.0, 12.66, 'NO', 1644345923].
# The data from the 522 city call is as follows: [149812, 'sokoni', -6.4333, 39.55, 80.98, 79.0, 100.0, 12.88, 'TZ', 1644345924].
# The data from the 523 city call is as follows: [2057087, 'kupang', -10.1667, 123.5833, 79.61, 80.0, 99.0, 1.34, 'ID', 1644345924].
# The data from the 524 city call is as follows: [2399001, 'mayumba', -3.432, 10.6554, 78.1, 90.0, 96.0, 7.18, 'GA', 1644345924].
# The data from the 525 city call is as follows: [2420826, 'gaoual', 11.75, -13.2, 89.28, 8.0, 16.0, 5.66, 'GN', 1644345925].
# The data from the 526 city call is as follows: [1730622, 'anito', 12.4497, 125.2886, 77.36, 79.0, 100.0, 10.38, 'PH', 1644345925].
# The data from the 527 city call is as follows: [694558, 'semypolky', 50.7167, 30.9333, 34.83, 92.0, 100.0, 6.67, 'UA', 1644345925].
# The data from the 528 city call is as follows: [2361177, 'djibo', 14.1022, -1.6306, 79.75, 11.0, 0.0, 9.19, 'BF', 1644345926].
# The data from the 529 city call is as follows: [3441890, 'maldonado', -34.6667, -54.9167, 74.59, 54.0, 53.0, 9.51, 'UY', 1644345926].
# The data from the 530 city call is as follows: [1791464, 'wenling', 28.3669, 121.36, 43.92, 80.0, 100.0, 7.63, 'CN', 1644345926].
# The data from the 531 city call is as follows: [2012593, 'zeya', 53.75, 127.2667, -3.53, 97.0, 100.0, 3.11, 'RU', 1644345927].
# The data from the 532 city call is as follows: [2071860, 'esperance', -33.8667, 121.9, 57.04, 69.0, 12.0, 5.66, 'AU', 1644345927].
# The data from the 533 city call is as follows: [4852640, 'coralville', 41.6764, -91.5805, 55.63, 46.0, 0.0, 6.91, 'US', 1644345927].
# The data from the 534 city call is as follows: [187585, 'marsabit', 2.3284, 37.9899, 73.47, 34.0, 100.0, 8.08, 'KE', 1644345928].
# The data from the 535 city call is as follows: [1816234, 'bozhou', 33.8772, 115.7703, 34.63, 78.0, 100.0, 4.45, 'CN', 1644345928].
# The data from the 536 city call is as follows: [3396601, 'lago da pedra', -4.3333, -45.1667, 86.07, 70.0, 38.0, 1.59, 'BR', 1644345928].
# The data from the 537 city call is as follows: [3347719, 'luena', -11.7833, 19.9167, 62.49, 95.0, 91.0, 4.61, 'AO', 1644345929].
# The data from the 538 city call is as follows: [2246451, 'saint-louis', 16.3333, -15, 96.44, 8.0, 0.0, 9.66, 'SN', 1644345930].
# The data from the 539 city call is as follows: [3584003, 'puerto el triunfo', 13.2833, -88.55, 94.06, 50.0, 13.0, 11.48, 'SV', 1644345931].
# Failed on 540 try.
# The data from the 541 city call is as follows: [2017215, 'sangar', 63.9242, 127.4739, -38.56, 100.0, 100.0, 1.54, 'RU', 1644345932].
# The data from the 542 city call is as follows: [6201197, 'lahij', 13.1667, 44.5833, 71.35, 78.0, 89.0, 8.01, 'YE', 1644345932].
# The data from the 543 city call is as follows: [2127202, 'anadyr', 64.75, 177.4833, -28.7, 68.0, 91.0, 13.42, 'RU', 1644345932].
# The data from the 544 city call is as follows: [2186111, 'ngunguru', -35.6167, 174.5, 74.16, 99.0, 81.0, 10.11, 'NZ', 1644345933].
# The data from the 545 city call is as follows: [637219, 'seinajoki', 62.7945, 22.8282, 30.78, 79.0, 75.0, 6.91, 'FI', 1644345749].
# The data from the 546 city call is as follows: [237379, 'ndele', 8.4109, 20.6473, 76.24, 16.0, 5.0, 4.76, 'CF', 1644345933].
# The data from the 547 city call is as follows: [2112802, 'hasaki', 35.7333, 140.8333, 32.4, 66.0, 88.0, 13.02, 'JP', 1644345934].
# The data from the 548 city call is as follows: [2271968, 'aljezur', 37.3191, -8.8033, 56.84, 79.0, 0.0, 12.41, 'PT', 1644345934].
# The data from the 549 city call is as follows: [3524527, 'la trinitaria', 16.1167, -92.05, 58.26, 79.0, 100.0, 5.39, 'MX', 1644345935].
# Failed on 550 try.
# Failed on 551 try.
# The data from the 552 city call is as follows: [4219934, 'roswell', 34.0232, -84.3616, 56.71, 40.0, 0.0, 8.05, 'US', 1644345547].
# The data from the 553 city call is as follows: [2377450, 'nouakchott', 18.0858, -15.9785, 84.13, 43.0, 0.0, 11.34, 'MR', 1644345752].
# The data from the 554 city call is as follows: [2332515, 'lafia', 8.4833, 8.5167, 86.41, 12.0, 63.0, 4.65, 'NG', 1644345935].
# The data from the 555 city call is as follows: [4992232, 'escanaba', 45.7453, -87.0646, 32.43, 70.0, 0.0, 11.5, 'US', 1644345936].
# The data from the 556 city call is as follows: [1495626, 'pangody', 65.85, 74.4859, -3.82, 84.0, 83.0, 15.26, 'RU', 1644345936].
# The data from the 557 city call is as follows: [4362001, 'mayo', 38.8876, -76.5119, 48.24, 41.0, 0.0, 9.22, 'US', 1644345936].
# The data from the 558 city call is as follows: [2174444, 'bowen', -20.0167, 148.2333, 70.02, 74.0, 8.0, 6.04, 'AU', 1644345937].
# Failed on 559 try.
# Failed on 560 try.
# The data from the 561 city call is as follows: [3423146, 'ilulissat', 69.2167, -51.1, -5.78, 65.0, 20.0, 19.57, 'GL', 1644345938].
# The data from the 562 city call is as follows: [1847947, 'shingu', 33.7333, 135.9833, 35.91, 83.0, 100.0, 6.76, 'JP', 1644345938].
# The data from the 563 city call is as follows: [510911, 'pervomayskiy', 53.2485, 40.2871, 33.13, 99.0, 100.0, 5.35, 'RU', 1644345938].
# The data from the 564 city call is as follows: [2512186, 'puerto del rosario', 28.5004, -13.8627, 73.15, 49.0, 53.0, 1.14, 'ES', 1644345939].
# The data from the 565 city call is as follows: [88319, 'benghazi', 32.1167, 20.0667, 55.53, 49.0, 5.0, 26.26, 'LY', 1644345939].
# Failed on 566 try.
# The data from the 567 city call is as follows: [2157698, 'mildura', -34.2, 142.15, 71.56, 60.0, 100.0, 1.14, 'AU', 1644345940].
# The data from the 568 city call is as follows: [5955902, 'fort nelson', 58.8053, -122.7002, -0.81, 78.0, 100.0, 4.61, 'CA', 1644345940].
# The API query is complete.
# --------------------
# The loop ran for 569 times to the 568 index.
# There were 49 errors found when trying to look up weather for cities.
# The removed cities from the original list are as follows: ['belushya guba', 'tsihombe', 'makung', 'chagda', 'saleaula', 'marcona', 'tumannyy', 'ruatoria', 'barentsburg', 'halalo', 'kadykchan', 'vaitupu', 'barawe', 'grand river south east', 'togui', 'samalaeulu', 'alotau', 'mys shmidta', 'naftah', 'khonuu', 'bolungarvik', 'toliary', 'el badari', 'lolua', 'zhanatas', 'palabuhanratu', 'sentyabrskiy', 'tiruvottiyur', 'coulihaut', 'paucartambo', 'karaul', 'amderma', 'urdzhar', 'tarudant', 'guelengdeng', 'grand centre', 'barbar', 'samusu', 'dujuma', 'macaboboni', 'gurskoye', 'kamenskoye', 'bargal', 'longlac', 'kac', 'ye', 'ondorhaan', 'tir pol', 'saryshagan'].
# --------------------
# The cities list is now 569 long.

# %%
# Convert the UNIX timestamp into a readable date/time format
data_df['Date'] = pd.to_datetime(data_df['DT'], unit='s')

# Verify the length and format of the DataFrame
print(f'The DataFrame is {len(data_df)} rows.')
data_df.head()
# Out:
# The DataFrame is 520 rows.
#    City ID         City  Latitude  Longitude  Max Temperature (F)  \
# 0  6185377  yellowknife   62.4560  -114.3525               -15.59
# 1  2068110    kununurra  -15.7667   128.7333                80.58
# 2  2027275         bada   51.3920   109.8717                 0.21
# 3  5880054       barrow   71.2906  -156.7887               -30.98
# 4  1640902       kawalu   -7.3817   108.2082                73.92
#
#    Humidity (%)  Clouds (%)  Wind Speed (mph) Country          DT  \
# 0          90.0        75.0              4.61      CA  1644345519
# 1          89.0        75.0              0.00      AU  1644345732
# 2          98.0       100.0              2.95      RU  1644345733
# 3         100.0        20.0              8.05      US  1644345742
# 4          92.0       100.0              1.03      ID  1644345742
#
#                  Date
# 0 2022-02-08 18:38:39
# 1 2022-02-08 18:42:12
# 2 2022-02-08 18:42:13
# 3 2022-02-08 18:42:22
# 4 2022-02-08 18:42:22

# %%
# Verify the DataFrame has humidity <= 100% (no errors in the data)
data_df = data_df[data_df['Humidity (%)'] <= 100]
print(f'The clean DataFrame is {len(data_df)} rows.')
# Out:
# The clean DataFrame is 520 rows.

# %%
# Save the clean DataFrame to a CSV file
data_df.to_csv(output_data_file, index=False, header=True)

# %% [markdown]
# ## Scatter Plot Temperature vs Latitude

# %%
# Create a scatter plot showing the relationship between Temperature and Latitude
plt.scatter(data_df['Latitude'], data_df['Max Temperature (F)'])
plt.title('Temperature vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.xlim(-90,90)
plt.ylim(data_df['Max Temperature (F)'].min()*.9, data_df['Max Temperature (F)'].max()*1.10)
plt.tight_layout()
plt.savefig('Temp_Lat.png')
plt.show()

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot Humidity vs Latitude

# %%
# Create a scatter plot showing the relationship between Humidity and Latitude
plt.scatter(data_df['Latitude'], data_df['Humidity (%)'])
plt.title('Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(-90,90)
plt.ylim(data_df['Humidity (%)'].min()*.9, data_df['Humidity (%)'].max()*1.10)
plt.tight_layout()
plt.savefig('Humidity_Lat.png')
plt.show()

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot Cloud Cover vs Latitude

# %%
# Create a scatter plot showing the relationship between Cloud Cover and Latitude
plt.scatter(data_df['Latitude'], data_df['Clouds (%)'])
plt.title('Cloud Cover vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloud Cover (%)')
plt.xlim(-90,90)
plt.ylim(data_df['Clouds (%)'].min()*.9, data_df['Clouds (%)'].max()*1.10)
plt.tight_layout()
plt.savefig('Clouds_Lat.png')
plt.show()

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot Wind Speed vs Latitude

# %%
# Create a scatter plot showing the relationship between Wind Speed and Latitude
plt.scatter(data_df['Latitude'], data_df['Wind Speed (mph)'])
plt.title('Wind Speed vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(-90,90)
plt.ylim(data_df['Wind Speed (mph)'].min()*.9, data_df['Wind Speed (mph)'].max()*1.10)
plt.tight_layout()
plt.savefig('Wind_Lat.png')
plt.show()

# %% [markdown]
# ## Write Up

# %%
# Split the DataFrame into Northern and Southern Hemispheres
north_data_df = data_df[data_df['Latitude'] >= 0]
south_data_df = data_df[data_df['Latitude'] < 0]

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Temperature vs Latitude in Northern Hemisphere

# %%
# Create a scatter plot showing the relationship between Temperature and Northern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = north_data_df['Latitude']      
y_values = north_data_df['Max Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(north_data_df['Latitude'], north_data_df['Max Temperature (F)'])
plt.title('Northern Hemisphere: Temperature vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.xlim(0,90)
plt.ylim(north_data_df['Max Temperature (F)'].min()*.9, north_data_df['Max Temperature (F)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(40, 80),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Temp_NLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = north_data_df['Latitude']      
y_values = north_data_df['Max Temperature (F)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is -0.86

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Temperature vs Latitude in Southern Hemisphere

# %%
# Create a scatter plot showing the relationship between Temperature and Southern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = south_data_df['Latitude']      
y_values = south_data_df['Max Temperature (F)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(south_data_df['Latitude'], south_data_df['Max Temperature (F)'])
plt.title('Southern Hemisphere: Temperature vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.xlim(-90,0)
plt.ylim(south_data_df['Max Temperature (F)'].min()*.9, south_data_df['Max Temperature (F)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(-80,90),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Temp_SLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = south_data_df['Latitude']      
y_values = south_data_df['Max Temperature (F)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.51

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Humidity vs Latitude in Northern Hemisphere

# %%
# Create a scatter plot showing the relationship between Humidity and Northern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = north_data_df['Latitude']      
y_values = north_data_df['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(north_data_df['Latitude'], north_data_df['Humidity (%)'])
plt.title('Northern Hemisphere: Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(0,90)
plt.ylim(north_data_df['Humidity (%)'].min()*.9, north_data_df['Humidity (%)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(50, 35),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Humidity_NLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = north_data_df['Latitude']      
y_values = north_data_df['Humidity (%)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.51

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Humidity vs Latitude in Southern Hemisphere

# %%
# Create a scatter plot showing the relationship between Humidity and Southern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = south_data_df['Latitude']      
y_values = south_data_df['Humidity (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(south_data_df['Latitude'], south_data_df['Humidity (%)'])
plt.title('Southern Hemisphere: Humidity vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(-90, 0)
plt.ylim(south_data_df['Humidity (%)'].min()*.9, south_data_df['Humidity (%)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(-80, 80),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Humidity_SLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = south_data_df['Latitude']      
y_values = south_data_df['Humidity (%)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.18

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Cloudiness vs Latitude in Northern Hemisphere

# %%
# Create a scatter plot showing the relationship between Cloudiness and Northern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = north_data_df['Latitude']      
y_values = north_data_df['Clouds (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(north_data_df['Latitude'], north_data_df['Clouds (%)'])
plt.title('Northern Hemisphere: Cloudiness vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(0,90)
plt.ylim(north_data_df['Clouds (%)'].min()*.9, north_data_df['Clouds (%)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(50, 40),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Clouds_NLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = north_data_df['Latitude']      
y_values = north_data_df['Clouds (%)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.28

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Cloudiness vs Latitude in Southern Hemisphere

# %%
# Create a scatter plot showing the relationship between Cloudiness and Southern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = south_data_df['Latitude']      
y_values = south_data_df['Clouds (%)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(south_data_df['Latitude'], south_data_df['Clouds (%)'])
plt.title('Southern Hemisphere: Cloudiness vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(-90,0)
plt.ylim(south_data_df['Clouds (%)'].min()*.9, south_data_df['Clouds (%)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(50, 40),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Clouds_SLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = south_data_df['Latitude']      
y_values = south_data_df['Clouds (%)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.25

# %% [markdown]
# ### Write Up

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Wind Speed vs Latitude in Northern Hemisphere

# %%
# Create a scatter plot showing the relationship between Wind Speed and Northern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = north_data_df['Latitude']      
y_values = north_data_df['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(north_data_df['Latitude'], north_data_df['Wind Speed (mph)'])
plt.title('Northern Hemisphere: Wind Speed vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(0,90)
plt.ylim(north_data_df['Wind Speed (mph)'].min()*.9, north_data_df['Wind Speed (mph)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(50, 15),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Wind_NLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = north_data_df['Latitude']      
y_values = north_data_df['Wind Speed (mph)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is 0.15

# %% [markdown]
# ## Scatter Plot with Regression Analysis of Wind Speed vs Latitude in Southern Hemisphere

# %%
# Create a scatter plot showing the relationship between Wind Speed and Southern Latitude
# Add the linear regression model and equation to the scatter plot

# Calculate the liner regression equation
x_values = south_data_df['Latitude']      
y_values = south_data_df['Wind Speed (mph)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)      
regress_values = x_values * slope + intercept    
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))    

# Create the scatter plot and add the regression line
plt.scatter(south_data_df['Latitude'], south_data_df['Wind Speed (mph)'])
plt.title('Southern Hemisphere: Wind Speed vs Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(-90, 0)
plt.ylim(south_data_df['Wind Speed (mph)'].min()*.9, south_data_df['Wind Speed (mph)'].max()*1.10)
plt.plot(x_values,regress_values,"r-")               # plot regression line
plt.annotate(line_eq,(50, 15),fontsize=15,color="red") 
plt.tight_layout()
plt.savefig('Wind_SLat.png')
plt.show()

# Calculate the Pearson correlation coefficient.  
x_values = south_data_df['Latitude']      
y_values = south_data_df['Wind Speed (mph)']
correlation = sem.pearsonr(x_values, y_values)
print(f"The Pearson Correlation Coefficient is {round(correlation[0],2)}")
print("")
# Out:
# The Pearson Correlation Coefficient is -0.11

# %% [markdown]
# ### Write Up
